# %% [markdown]
# https://docs.opencv.org/3.1.0/d9/d8b/tutorial_py_contours_hierarchy.html

# %%
import cv2
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt
import time

# %%
i = 16
img = cv2.imread(f'../source_images/beiersdorf_20154.pdf_page_{i}.png')
img_gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
edges = cv2.Canny(img_gray, 100, 200)
Image.fromarray(edges)
kernel = np.ones((6,6), np.float32)/25
ret, mask = cv2.threshold(edges, 0, 255, cv2.THRESH_BINARY)
dilation = cv2.dilate(mask, kernel, iterations=3)
closing = cv2.morphologyEx(dilation, cv2.MORPH_CLOSE, kernel)
contours, hierarchy = cv2.findContours(closing, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
print(len(contours))
blocks = []
for i, c in enumerate(contours):
    area = cv2.contourArea(c)
    x,y,w,h = cv2.boundingRect(c)
    blocks.append((x,y,w,h))
    cv2.rectangle(img, (x,y), (x+w, y+h), (0,0,255), 1)
    cv2.putText(img, str(i), (x,y), cv2.FONT_HERSHEY_SIMPLEX, 1, (0,0,0))
Image.fromarray(dilation)
Image.fromarray(closing)
Image.fromarray(img)
# Out:
# 6
# <PIL.Image.Image image mode=RGB size=1241x1536 at 0x7FB4BC3C8208>

# %%
# [next contour, previous contours, child contour, parent contour]
print(len(hierarchy[0]))
for i, h in enumerate(hierarchy[0]):
    print(i, h)
# Out:
# 2104
# 0 [ 1 -1 -1 -1]
# 1 [ 2  0 -1 -1]
# 2 [ 3  1 -1 -1]
# 3 [ 4  2 -1 -1]
# 4 [ 5  3 -1 -1]
# 5 [ 6  4 -1 -1]
# 6 [ 7  5 -1 -1]
# 7 [ 8  6 -1 -1]
# 8 [ 9  7 -1 -1]
# 9 [10  8 -1 -1]
# 10 [11  9 -1 -1]
# 11 [12 10 -1 -1]
# 12 [13 11 -1 -1]
# 13 [14 12 -1 -1]
# 14 [15 13 -1 -1]
# 15 [16 14 -1 -1]
# 16 [17 15 -1 -1]
# 17 [18 16 -1 -1]
# 18 [19 17 -1 -1]
# 19 [20 18 -1 -1]
# 20 [21 19 -1 -1]
# 21 [22 20 -1 -1]
# 22 [23 21 -1 -1]
# 23 [24 22 -1 -1]
# 24 [25 23 -1 -1]
# 25 [26 24 -1 -1]
# 26 [27 25 -1 -1]
# 27 [28 26 -1 -1]
# 28 [29 27 -1 -1]
# 29 [30 28 -1 -1]
# 30 [31 29 -1 -1]
# 31 [32 30 -1 -1]
# 32 [33 31 -1 -1]
# 33 [34 32 -1 -1]
# 34 [35 33 -1 -1]
# 35 [36 34 -1 -1]
# 36 [37 35 -1 -1]
# 37 [38 36 -1 -1]
# 38 [39 37 -1 -1]
# 39 [40 38 -1 -1]
# 40 [41 39 -1 -1]
# 41 [42 40 -1 -1]
# 42 [43 41 -1 -1]
# 43 [44 42 -1 -1]
# 44 [45 43 -1 -1]
# 45 [46 44 -1 -1]
# 46 [47 45 -1 -1]
# 47 [48 46 -1 -1]
# 48 [49 47 -1 -1]
# 49 [50 48 -1 -1]
# 50 [51 49 -1 -1]
# 51 [52 50 -1 -1]
# ...
